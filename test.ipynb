# %%
from Bio import Entrez
import xml.etree.ElementTree as ET

handle = Entrez.efetch(db="pmc", id=5721143, retmode='xml')
record = handle.read()
handle.close()
root = ET.fromstring(record)

# %%
# print record
print root.findall('.//article-title')
#print 'TITLE: ', root[0][0][1][4][0].text
#print 'ABSTRACT: ', root[0][0][1][17][0].text
print record
# Out:
# [<Element 'article-title' at 0x7f331279af50>, <Element 'article-title' at 0x7f33280618d0>, <Element 'article-title' at 0x7f332806d0d0>, <Element 'article-title' at 0x7f332806d550>, <Element 'article-title' at 0x7f332806dd90>, <Element 'article-title' at 0x7f3328079890>, <Element 'article-title' at 0x7f33280851d0>, <Element 'article-title' at 0x7f3328085890>, <Element 'article-title' at 0x7f3328092390>, <Element 'article-title' at 0x7f3328092c90>]
# <?xml version="1.0" ?>
# <!DOCTYPE pmc-articleset PUBLIC "-//NLM//DTD ARTICLE SET 2.0//EN" "https://dtd.nlm.nih.gov/ncbi/pmc/articleset/nlm-articleset-2.0.dtd">
# <pmc-articleset><article xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:mml="http://www.w3.org/1998/Math/MathML" article-type="brief-report">
#   <?properties open_access?>
#   <front>
#     <journal-meta>
#       <journal-id journal-id-type="nlm-ta">Genome Announc</journal-id>
#       <journal-id journal-id-type="iso-abbrev">Genome Announc</journal-id>
# ...
